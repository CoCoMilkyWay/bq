# %%
import dai

table = "cn_stock_bar1m_derived"

# 获取 schema
result = dai.query(f"DESCRIBE {table}")
schema_df = result.df()[['column_name', 'column_type']]
schema_df

# 根据是否有 date 字段选择查询方式
# sample = dai.query(f"SELECT * FROM {table} LIMIT 1", full_db_scan=True)
# sample_df = sample.df()
# sample_df
# Out:
#                column_name   column_type
# 0                     date  TIMESTAMP_NS
# 1                     time       INTEGER
# 2              trading_day       INTEGER
# 3      total_10_bid_volume        BIGINT
# 4      total_10_ask_volume        BIGINT
# ..                     ...           ...
# 140  initiative_bid_amount        DOUBLE
# 141  initiative_bid_volume        BIGINT
# 142    initiative_ask_rate         FLOAT
# 143  initiative_ask_volume        BIGINT
# 144  initiative_ask_amount        DOUBLE
#
# [145 rows x 2 columns]
