# %%
import dai
df = dai.query("""
    SELECT *
    FROM trading_days""",
    filters={"date": ["2022-01-01", "2022-12-31"]}
).df()

df
# Out:
#            date market_code
# 0    2022-01-03          US
# 1    2022-01-03          HK
# 2    2022-01-03          IT
# 3    2022-01-03          DE
# 4    2022-01-04          US
# ...         ...         ...
# 1741 2022-12-30          HK
# 1742 2022-12-30          JP
# 1743 2022-12-30          UK
# 1744 2022-12-30          IT
# 1745 2022-12-30          DE
#
# [1746 rows x 2 columns]

# %%
# %%sql
# select * from cn_stock_bar1d LIMIT 1;
# Out:
# ┌─────────────────────┬────────────┬─────────┬───────────────────┬────────────────────┬────────────────────┬────────────────────┬────────────────────┬────────────────────┬─────────┬─────────────┬────────────┬───────────────────────┬──────────────────────┬────────────────────┬────────────────────┐
# │        date         │ instrument │  name   │   adjust_factor   │     pre_close      │        open        │       close        │        high        │        low         │ volume  │ deal_number │   amount   │     change_ratio      │         turn         │    upper_limit     │    lower_limit     │
# │    timestamp_ns     │  varchar   │ varchar │      double       │       double       │       double       │       double       │       double       │       double       │  int64  │    int32    │   double   │        double         │        double        │       double       │       double       │
# ...
